# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
# Helper functions
from anthropic.types import Message


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[], tools=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
web_search_schema = {
    "type": "web_search_20250305",
    "name": "web_search",
    "max_uses": 5,
    "allowed_domains": ["nih.gov"],
}

# %%
messages = []
add_user_message(
    messages,
    """
    What's the best exercise for gaining leg muscle?
    """,
)
response = chat(messages, tools=[web_search_schema])
response
# Out:
# Message(id='msg_016UP91x32b8qGzV31LdMHUQ', container=None, content=[TextBlock(citations=None, text="The best exercises for gaining leg muscle are compound movements that target multiple muscle groups. Here are the most effective ones:\n\n## Top Exercises for Leg Muscle Growth\n\n**1. Barbell Back Squat**\n- Often considered the king of leg exercises\n- Targets quadriceps, glutes, hamstrings, and core\n- Allows for heavy loading, promoting maximum muscle growth\n\n**2. Romanian Deadlift (RDL)**\n- Excellent for hamstrings and glutes\n- Also strengthens lower back and core\n- Great for posterior chain development\n\n**3. Bulgarian Split Squat**\n- Unilateral exercise that addresses muscle imbalances\n- Heavily targets quads and glutes\n- Requires less weight than barbell squats while still being highly effective\n\n**4. Leg Press**\n- Allows for very heavy loading with less technical demand\n- Great for isolating leg muscles when form is solid\n- Good option if you have back issues\n\n**5. Walking Lunges**\n- Works quads, glutes, and hamstrings\n- Improves balance and unilateral strength\n- Functional movement pattern\n\n## Key Principles for Leg Muscle Growth\n\n- **Progressive Overload**: Gradually increase weight, reps, or volume over time\n- **Proper Form**: Prioritize technique to maximize muscle activation and prevent injury\n- **Variety**: Incorporate different exercises to target all leg muscles comprehensively\n- **Recovery**: Legs are large muscle groups that need adequate rest (48-72 hours between intense sessions)\n- **Nutrition**: Consume sufficient protein and calories to support muscle growth\n\nIf you're just starting out, focus on mastering the squat and Romanian deadlift with lighter weights before progressing to heavier loads. For maximum growth, aim for 3-4 sets of 8-12 reps for most exercises.", type='text')], model='claude-sonnet-4-5-20250929', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', input_tokens=2228, output_tokens=420, server_tool_use=None, service_tier='standard'))
